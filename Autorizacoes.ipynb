# %%
import numpy as np
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import colorsys
plt.style.use('seaborn-talk')
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv('arquivos-de-dados_tb-base-autorizacoes.csv',error_bad_lines=False, sep=",")

# %%
df
# Out:
#          VISAO                                      NR_CONTA  VALOR_TRANSACAO  \
# 0       202110  jBP367fedDdbHlQz2zQDhW1EkQzio2P2O6/TPftXe0A=           777.76
# 1       202110  ufYUtvt1Pb4/HwzGEwWrMYwdEWwxFUu/zkU0zBNcY3Y=            59.70
# 2       202110  tSg4Py+2ud5HY3744Qp0KQOwX7rxPFumF2qI3D6wCRI=            14.48
# 3       202110  RNRSLGtDs5NUrl8ZRyBnxTj5n6Hsm32+UTF69PxAPpY=           117.13
# 4       202110  MPaannE4neO6zlwYTjfGshdOSKFvbjUnuMZQGSxVz/w=           208.54
# ...        ...                                           ...              ...
# 669363  202110  JhqJX8mobAdNsqr+9nYnYio2ZbAKJSKMU2IPKZh/sXg=          4272.03
# 669364  202110  onyx5JOnr9jNy+1XUq+k+6JolWUSTtf/i5YvdRFO00Q=         10723.38
# 669365  202110  tvbHA9yYUQ21In3g0LIRQGzxWkowaYZMb8euBw7GYdo=           320.00
# 669366  202110  JPUfwq8JCfCbnao85++YyzqNneumzEO/E6tfqJ0XinY=          3000.00
# 669367  202110  zToBmqZTiUV8oiucDnTqWJTDvdAiw9OQh52uhyJCJqA=          4378.50
#
# ...

# %%
df.dtypes
# Out:
# VISAO                int64
# NR_CONTA            object
# VALOR_TRANSACAO    float64
# N_PARCELAS           int64
# FG_ONOFFCASE        object
# TIPO_TRNS           object
# DATA_TRANSACAO       int64
# NOME_ESTAB          object
# ASTIPO_ESTAB         int64
# dtype: object

# %%
df = df.rename(columns={"VISAO":"VISAO", "NR_CONTA": "NR_CONTA", "VALOR_TRANSACAO":"VALOR_TRANSACAO", "N_PARCELAS":"N_PARCELAS", "FG_ONOFFCASE":"ON/OFF_ATACADAO", "TIPO_TRNS": "TIPO_TRNS", "DATA_TRANSACAO":"DATA_TRANSACAO"})

# %%
df
# Out:
#          VISAO                                      NR_CONTA  VALOR_TRANSACAO  \
# 0       202110  jBP367fedDdbHlQz2zQDhW1EkQzio2P2O6/TPftXe0A=           777.76
# 1       202110  ufYUtvt1Pb4/HwzGEwWrMYwdEWwxFUu/zkU0zBNcY3Y=            59.70
# 2       202110  tSg4Py+2ud5HY3744Qp0KQOwX7rxPFumF2qI3D6wCRI=            14.48
# 3       202110  RNRSLGtDs5NUrl8ZRyBnxTj5n6Hsm32+UTF69PxAPpY=           117.13
# 4       202110  MPaannE4neO6zlwYTjfGshdOSKFvbjUnuMZQGSxVz/w=           208.54
# ...        ...                                           ...              ...
# 669363  202110  JhqJX8mobAdNsqr+9nYnYio2ZbAKJSKMU2IPKZh/sXg=          4272.03
# 669364  202110  onyx5JOnr9jNy+1XUq+k+6JolWUSTtf/i5YvdRFO00Q=         10723.38
# 669365  202110  tvbHA9yYUQ21In3g0LIRQGzxWkowaYZMb8euBw7GYdo=           320.00
# 669366  202110  JPUfwq8JCfCbnao85++YyzqNneumzEO/E6tfqJ0XinY=          3000.00
# 669367  202110  zToBmqZTiUV8oiucDnTqWJTDvdAiw9OQh52uhyJCJqA=          4378.50
#
# ...

# %%
df.groupby("ON/OFF_ATACADAO")["VALOR_TRANSACAO"].sum()
# Out:
# ON/OFF_ATACADAO
# OFF US    57411757.69
# ON US     30491262.50
# Name: VALOR_TRANSACAO, dtype: float64

# %%
df.groupby("ON/OFF_ATACADAO")["VALOR_TRANSACAO"].sum().sort_values(ascending=True).plot.barh(title="Total Produtos Vendidos")
plt.xlabel("VALOR_TRANSACAO")
plt.ylabel("ON/OFF_ATACADAO");
